# %% [markdown]
# <a href="https://colab.research.google.com/github/SuryaSankar18/FMML_ASSIGNMENTS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-08 16:10:05--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  99.9MB/s    in 0.7s
#
# 2024-04-08 16:10:07 (99.9 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 3506 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 35032  1601.04862v1  Anthropomimetic robots are robots that sense, ...    cs
# 10841  1502.01493v1  This paper presents an original approach for j...  stat
# 23510   1304.0023v3  The two-dimensional Gabor function is adapted ...    cs
# 22328  1602.02964v4  We propose a nonparametric statistical test fo...  stat
# 6258   1610.05925v1  We propose a new class of determinantal point ...  stat
# ...             ...                                                ...   ...
# 10537   1207.4118v1  Ancestral graph models, introduced by Richards...  stat
# 28594  1707.02069v2  High level understanding of sequential visual ...    cs
# 8177    1408.5400v1  A key topic in classification is the accuracy ...    cs
# 22789  1706.08699v1  Power supply from renewable resources is on a ...  stat
# 21482  1803.03021v1  In multiagent environments, the capability of ...    cs
#
#                                                    title  year  \
# 35032  Scalability in Neural Control of Musculoskelet...  2016
# 10841  A mixture Cox-Logistic model for feature selec...  2015
# 23510  The two-dimensional Gabor function adapted to ...  2013
# 22328                   A Kernel Test of Goodness of Fit  2016
# 6258   Learning Determinantal Point Processes in Subl...  2016
# ...                                                  ...   ...
# 10537  Iterative Conditional Fitting for Gaussian Anc...  2012
# 28594  A spatiotemporal model with visual attention f...  2017
# 8177   Hierarchical Adaptive Structural SVM for Domai...  2014
# 22789       Two-Stage Hybrid Day-Ahead Solar Forecasting  2017
# 21482  SA-IGA: A Multiagent Reinforcement Learning Me...  2018
#
#                                                 keywords
# 35032  [anthropomimetic, definition, anthropomimetic,...
# 10841  [classifying, subgroups, generalized, conditio...
# 23510  [dimensional, statistics, distribution, parame...
# 22328  [nonparametric, statistical, determines, gener...
# 6258   [determinantal, processes, manipulated, infere...
# ...                                                  ...
# 10537  [ancestral, introduced, richardson, generalize...
# 28594  [understanding, sequential, important, especia...
# 8177   [classification, distribution, recognized, cla...
# 22789  [renewable, resources, forecasted, renewable, ...
# 21482  [multiagent, environments, capability, importa...
#
# [5604 rows x 6 columns]

# %%
df['keywords']
# Out:
# 35032    [anthropomimetic, definition, anthropomimetic,...
# 10841    [classifying, subgroups, generalized, conditio...
# 23510    [dimensional, statistics, distribution, parame...
# 22328    [nonparametric, statistical, determines, gener...
# 6258     [determinantal, processes, manipulated, infere...
#                                ...
# 3623     [classification, interested, algorithms, class...
# 6312     [concerned, primarily, interactions, individua...
# 22201    [knowledge, performance, methodology, covariat...
# 32442    [semisupervised, framework, improving, control...
# 4156     [techniques, especially, predictive, recogniti...
# Name: keywords, Length: 7006, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 9307 words.
# Out of those 4829 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6fd87c80-2af4-4763-9569-da551ce53a63" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6fd87c80-2af4-4763-9569-da551ce53a63")) {                    Plotly.newPlot(                        "6fd87c80-2af4-4763-9569-da551ce53a63",                        [{"x":["naturally","controlled","definition","development","requirements","cerebellar","incorporated","controller","framework","consumption","principle","neuromorphic","realization","implements","extensibility","computing","scalability","actuation","physically","compliant","demonstrated","musculoskeletal","combining","conditioned","predicting","algorithm","selection","maximizing","informative","regression","likelihood","subgroups","expressed","classifying","regularized","validation","probability","coordinate","synthetic","minimizing","outperforms","selecting","generalized","estimated","classification","dimensional","controlling","distributions","receptive","correlated","multiscale","invariance","generated","reconstruction","analytical","equivalent","additional","properties","biological","different","functions","computation","outperform","correctly","frequencies","correlations","frequency","parameterized","uniformly","pronounced","distribution","characterized","significantly","resulting","statistics","magnitude","parameter","approximated","responses","represent","comparison","strategies","dependent","environments","estimates","orientation","parameters","performance","convergence","determines","constructed","approximate","quantiles","nonparametric","statistical","evaluating","complexity","divergence","quantifying","gradients","statistic","reproducing","estimation","bootstrap","procedure","criticism","empirical","factorization","exponentially","formulation","determinantal","approximation","modelling","potentially","proportions","particularly","continuous","conditional","summarization","processes","inference","documents","sentences","application","sublinear","manipulated","mechanical","annotated","annotation","introduce","requiring","indistinguishable","categories","annotations","crowdsourcing","similarity","appearance","automatically","expectation","optimization","efficiently","maximization","comparable","constraint","submodular","sequential","interestingness","compressing","redundancy","applications","algorithms","structural","associated","interpretability","subsequence","furthermore","usefulness","probabilistic","efficient","description","demonstrate","interleaving","describes","designing","attention","verification","increased","important","monitored","extraction","validated","generation","proliferation","obtaining","identifying","successfully","maintenance","discovered","precision","information","extracting","transcribes","independent","integration","shortcomings","predictions","pipelines","practical","recordings","incomplete","transcriptions","competitive","contribution","automatic","replacing","recognition","characters","advocates","achieving","processing"],"y":[49,29,47,125,46,2,25,17,527,29,54,7,8,9,3,130,27,3,8,2,107,2,107,27,73,846,156,32,33,112,68,3,28,42,37,47,160,27,132,46,254,35,78,54,514,157,18,119,14,25,7,24,178,95,25,61,117,215,47,757,233,148,92,34,10,27,61,19,23,6,197,29,246,154,57,56,120,14,24,124,142,105,84,72,83,28,229,901,120,14,58,117,1,12,148,59,227,26,10,28,7,8,198,7,134,2,162,39,24,89,3,125,49,52,4,72,94,102,16,112,206,60,76,247,4,3,10,82,60,323,35,8,71,66,14,147,75,192,43,311,160,35,106,91,12,70,0,5,18,422,602,77,108,19,1,172,27,153,416,70,532,4,84,47,165,39,42,360,4,115,45,130,6,33,65,85,10,18,78,715,70,3,115,43,14,83,13,116,8,36,4,110,68,197,21,409,27,4,91,318],"type":"bar"},{"x":["naturally","controlled","definition","development","requirements","ce ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4829,), (4829, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8644793152639088

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3333333333333333);'>Quantifying</span> <span style=''>Facial</span> <span style=''>Age</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.6861313868613138);'>Posterior</span> <span style=''>of</span> <span style=''>Age</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Comparisons</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>approach</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>annotating</span> <span style=''>large</span> <span style=''>quantity</span> <span style=''>of</span> <span style=''>in</span> <span style=''>the</span> <span style=''>wild</span> <span style=''>facial</span> <span style=''>images</span> <span style=''>with</span> <span style=''>high</span> <span style=''>quality</span> <span style='background-color:rgba(255, 0, 0, 0.6861313868613138);'>posterior</span> <span style=''>age</span> <span style='background-color:rgba(255, 0, 0, 0.43874643874643865);'>distribution</span> <span style=''>as</span> <span style=''>labels</span> <span style=''>Each</span> <span style='background-color:rgba(255, 0, 0, 0.6861313868613138);'>posterior</span> <span style=''>provides</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3088552915766739);'>probability</span> <span style='background-color:rgba(255, 0, 0, 0.43874643874643865);'>distribution</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.41304347826086946);'>estimated</span> <span style=''>ages</span> <span style=''>for</span> <span style=''>a</span> <span style=''>face</span> <span style=''>Our</span> <span style=''>approach</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>motivated</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.4609929078014184);'>observations</span> <span style=''>that</span> <span style=''>it</span> <span style=''>is</span> <span style=''>easier</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distinguish</span> <span style=''>who</span> <span style=''>is</span> <span style=''>the</span> <span style=''>older</span> <span style=''>of</span> <span style=''>two</span> <span style=''>people</span> <span style=''>than</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>determine</span> <span style=''>the</span> <span style=''>persons</span> <span style=''>actual</span> <span style=''>age</span> <span style=''>Given</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.4545454545454546);'>reference</span> <span style=''>database</span> <span style=''>with</span> <span style=''>samples</span> <span style=''>of</span> <span style=''>known</span> <span style=''>ages</span> <span style=''>and</span> <span style=''>a</span> <span style=''>dataset</span> <span style=''>to</span> <span style=''>label</span> <span style=''>we</span> <span style=''>can</span> <span style=''>transfer</span> <span style=''>reliable</span> <span style='background-color:rgba(0, 255, 0, 0.8082191780821919);'>annotations</span> <span style=''>from</span> <span style=''>the</span> <span style=''>former</span> <span style=''>to</span> <span style=''>the</span> <span style=''>latter</span> <span style=''>via</span> <span style=''>human</span> <span style=''>in</span> <span style=''>the</span> <span style=''>loop</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparisons</span> <span style=''>We</span> <span style=''>show</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>effective</span> <span style=''>way</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3267326732673267);'>transform</span> <span style=''>such</span> <span style='background- ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>The</span> <span style=''>Matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Generalized</span> <span style=''>Inverse</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Distribution</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Properties</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Applications</span> <br/><br/><span style=''>While</span> <span style=''>the</span> <span style=''>Matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Generalized</span> <span style=''>Inverse</span> <span style=''>Gaussian</span> <span style=''>(mathcalMGIG)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>arises</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>naturally</span> <span style=''>in</span> <span style=''>some</span> <span style=''>settings</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>over</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>symmetric</span> <span style=''>positive</span> <span style=''>semi</span> <span style=''>definite</span> <span style=''>matrices</span> <span style=''>certain</span> <span style=''>key</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effective</span> <span style=''>ways</span> <span style=''>of</span> <span style=''>sampling</span> <span style=''>from</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>have</span> <span style=''>not</span> <span style=''>been</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>carefully</span> <span style=''>studied</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>mathcalMGIG</span> <span style=''>is</span> <span style=''>unimodal</span> <span style=''>and</span> <span style=''>the</span> <span style=''>mode</span> <span style=''>can</span> <span style=''>be</span> <span style=''>obtained</span> <span style=''>by</span> <span style=''>solving</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algebraic</span> <span style=''>Riccati</span> <span style=''>Equation</span> <span style=''>(ARE)</span> <span style=''>equation</span> <span style=''>7</span> <span style=''>Based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>property</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>importance</span> <span style=''>sampling</span> <span style=''>method</span> <span style=''>for</span> <span style=''>the</span> <span style=''>mathcalMGIG</span> <span style=''>where</span> <span style=''>the</span> <span style=''>mode</span> <span style=''>of</span> <span style=''>the</span> <span style=''>proposal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>matches</span> <span style=''>that</span> <span style=''>of</span> <span style=''>the</span> <span style=''>target</span> <span style=''>The</span> <span style=''>proposed</span> <span style=''>sampling</span> <span style=''>method</span> <span style=''>is</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>than</span> <span style=''>existing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>32</span> <span style=''>33</span> <span style=''>which</span> <span style=''>use</s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Deep</span> <span style=''>Double</span> <span style=''>Sparsity</span> <span style=''>Encoder</span> <span style=''>Learning</span> <span style=''>to</span> <span style=''>Sparsify</span> <span style=''>Not</span> <span style=''>Only</span> <span style=''>Features</span> <span style=''>But</span> <span style=''>Also</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Parameters</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>emphasizes</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significance</span> <span style=''>to</span> <span style=''>jointly</span> <span style=''>exploit</span> <span style=''>the</span> <span style=''>problem</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.4216867469879517);'>parameter</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>in</span> <span style=''>the</span> <span style=''>context</span> <span style=''>of</span> <span style=''>deep</span> <span style=''>modeling</span> <span style=''>As</span> <span style=''>a</span> <span style=''>specific</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interesting</span> <span style=''>example</span> <span style=''>we</span> <span style=''>describe</span> <span style=''>the</span> <span style=''>deep</span> <span style=''>double</span> <span style=''>sparsity</span> <span style=''>encoder</span> <span style=''>(DDSE)</span> <span style=''>which</span> <span style=''>is</span> <span style=''>inspired</span> <span style=''>by</span> <span style=''>the</span> <span style=''>double</span> <span style=''>sparsity</span> <span style=''>model</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dictionary</span> <span style=''>learning</span> <span style=''>DDSE</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>simultaneously</span> <span style='background-color:rgba(255, 0, 0, 0.5);'>sparsities</span> <span style=''>the</span> <span style=''>output</span> <span style=''>features</span> <span style=''>and</span> <span style=''>the</span> <span style=''>learned</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>under</span> <span style=''>one</span> <span style=''>unified</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>In</span> <span style=''>addition</span> <span style=''>to</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intuitive</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpretation</span> <span style=''>DDSE</span> <span style=''>also</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>possesses</span> <span style=''>compact</span> <span style=''>model</span> <span style=''>size</span> <span style=''>and</span> <span style=''>low</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Extensive</span> <span style='background-color:rgba(255, 0, 0, 0.49222797927461137);'>simulations</span> <span style=''>compare</span> <span style=''>DDSE</span> <span style=''>with</span> <span style=''>several</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>carefully</span> <span style=''>designed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>baselines</span> <span style=''>and</span> <span style=''>verify</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistently</span> <span style=''>superior</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>DDSE</span> <span style=''>We</span> < ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>An</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Experimental</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Comparison</span> <span style=''>of</span> <span style=''>Hybrid</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithms</span> <span style=''>for</span> <span style=''>Bayesian</span> <span style=''>Network</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Structure</span> <span style=''>Learning</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>hybrid</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>Bayesian</span> <span style=''>network</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>learning</span> <span style=''>called</span> <span style=''>Hybrid</span> <span style=''>HPC</span> <span style=''>(H2PC)</span> <span style=''>It</span> <span style=''>first</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reconstructs</span> <span style=''>the</span> <span style=''>skeleton</span> <span style=''>of</span> <span style=''>a</span> <span style=''>Bayesian</span> <span style=''>network</span> <span style=''>and</span> <span style=''>then</span> <span style=''>performs</span> <span style=''>a</span> <span style=''>Bayesian</span> <span style=''>scoring</span> <span style=''>greedy</span> <span style=''>hill</span> <span style=''>climbing</span> <span style=''>search</span> <span style=''>to</span> <span style=''>orient</span> <span style=''>the</span> <span style=''>edges</span> <span style=''>It</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>subroutine</span> <span style=''>called</span> <span style=''>HPC</span> <span style=''>that</span> <span style=''>combines</span> <span style=''>ideas</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incremental</span> <span style=''>and</span> <span style=''>divide</span> <span style=''>and</span> <span style=''>conquer</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constraint</span> <span style=''>based</span> <span style=''>methods</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>the</span> <span style=''>parents</span> <span style=''>and</span> <span style=''>children</span> <span style=''>of</span> <span style=''>a</span> <span style=''>target</span> <span style=''>variable</span> <span style=''>We</span> <span style=''>conduct</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experimental</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparison</span> <span style=''>of</span> <span style=''>H2PC</span> <span style=''>against</span> <span style=''>Max</span> <span style=''>Min</span> <span style=''>Hill</span> <span style=''>Climbing</span> <span style=''>(MMHC)</span> <span style=''>which</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>currently</span> <span style=''>the</span> <span style=''>most</span> <span style=''>powerful</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>Bayesian</span> <span style=''>network</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>learning</span> <span style=''>on</span> <span style=''>several</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>benchmarks</span> <span style=''>with</span> <span style=''>various</span> <span style=''>data</span> <span style=''>sizes</span> <span style=''>Our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extensive</span> <span style=' ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	automatic (0.0699822380106572)
# 	experimental (0.1300177619893428)
# 	architecture (0.08490230905861457)
# 	segmentation (0.06962699822380107)
# 	processing (0.11296625222024867)
# 	information (0.2539964476021314)
# 	detection (0.12433392539964476)
# 	different (0.2689165186500888)
# 	convolutional (0.13143872113676733)
# 	recognition (0.1452930728241563)
#
# Some Statistics words are:
# 	stochastic (0.13517389745428468)
# 	variables (0.13983506633201864)
# 	statistical (0.1444962352097526)
# 	algorithm (0.39476514879885266)
# 	estimation (0.17353890283255646)
# 	theoretical (0.1538185729652205)
# 	distribution (0.18106848332735748)
# 	inference (0.2015059160989602)
# 	dimensional (0.18752240946575835)
# 	regression (0.17174614557188955)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="901ae0e8-cc10-4d00-8c40-6e925839f612" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("901ae0e8-cc10-4d00-8c40-6e925839f612")) {                    Plotly.newPlot(                        "901ae0e8-cc10-4d00-8c40-6e925839f612",                        [{"x":["naturally","controlled","definition","development","requirements","cerebellar","incorporated","controller","framework","consumption","principle","neuromorphic","realization","implements","extensibility","computing","scalability","actuation","physically","compliant","demonstrated","musculoskeletal","combining","conditioned","predicting","algorithm","selection","maximizing","informative","regression","likelihood","subgroups","expressed","classifying","regularized","validation","probability","coordinate","synthetic","minimizing","outperforms","selecting","generalized","estimated","classification","dimensional","controlling","distributions","receptive","correlated","multiscale","invariance","generated","reconstruction","analytical","equivalent","additional","properties","biological","different","functions","computation","outperform","correctly","frequencies","correlations","frequency","parameterized","uniformly","pronounced","distribution","characterized","significantly","resulting","statistics","magnitude","parameter","approximated","responses","represent","comparison","strategies","dependent","environments","estimates","orientation","parameters","performance","convergence","determines","constructed","approximate","quantiles","nonparametric","statistical","evaluating","complexity","divergence","quantifying","gradients","statistic","reproducing","estimation","bootstrap","procedure","criticism","empirical","factorization","exponentially","formulation","determinantal","approximation","modelling","potentially","proportions","particularly","continuous","conditional","summarization","processes","inference","documents","sentences","application","sublinear","manipulated","mechanical","annotated","annotation","introduce","requiring","indistinguishable","categories","annotations","crowdsourcing","similarity","appearance","automatically","expectation","optimization","efficiently","maximization","comparable","constraint","submodular","sequential","interestingness","compressing","redundancy","applications","algorithms","structural","associated","interpretability","subsequence","furthermore","usefulness","probabilistic","efficient","description","demonstrate","interleaving","describes","designing","attention","verification","increased","important","monitored","extraction","validated","generation","proliferation","obtaining","identifying","successfully","maintenance","discovered","precision","information","extracting","transcribes","independent","integration","shortcomings","predictions","pipelines","practical","recordings","incomplete","transcriptions","competitive","contribution","automatic","replacing","recognition","characters","advocates","achieving","processing","solutions","apparently","optimistic","heuristics","experience","heuristic","deterministic","performed","difference","advantages","advantageous","abstraction","inefficient","suboptimal","flexibility","minimising","composition","implementation","integrated","discovery","semantically","theoretical","scenarios","dependency","embeddings","uncertainty","dimensions","challenging","challenge","understanding","knowledge","primitive","automated","detecting","definitions","consequently","underlying","elementary","mathematics","construction","consistency","providing","narrowing","behaviours","illustrate","laboratory","researchers","experiments","behaviour","perspective","laboratories","subsequent","linguistic","conditioning","inten ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	interestingness
# 	abandonment
# 	mcallester
# 	resolvable
# 	kontorovich
# 	exponents
# 	bernstein
# 	supersparse
# 	criminology
# 	archetypes
# 	underdamped
# 	statistician
# 	encapsulate
# 	covariates
# 	acknowledging
# 	encompassing
# 	unveiling
# 	borderline
# 	retrospective
# 	psychiatry
# Some words which never appear in Statistics papers:
# 	cerebellar
# 	actuation
# 	compliant
# 	musculoskeletal
# 	transcribes
# 	transcriptions
# 	laboratories
# 	pheromone
# 	assertions
# 	extractive
# 	nonmonotonic
# 	logistics
# 	abduction
# 	grammatical
# 	explosive
# 	transferred
# 	conversational
# 	philosophers
# 	computability
# 	ambiguously

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.032232632887595e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8580599144079886
